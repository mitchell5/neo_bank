# %% [markdown]
# # Import Packages

# %%
#import data
import pandas as pd
import great_expectations as gx
import os

# %% [markdown]
# # Importing Data, Quick Look Through

# %%
#Devices

# %%
devices=pd.read_csv("/home/neobanking2025/projects/neo_bank/raw_data/devices.csv")
devices.head()
# Out:
#   string_field_0 string_field_1
# 0          Apple      user_6809
# 1          Apple      user_3636
# 2          Apple       user_510
# 3          Apple      user_3468
# 4          Apple      user_7036

# %%
len(devices)
# Out:
# 19431

# %%
devices=devices.drop_duplicates()

# %%
len(devices)
# Out:
# 19431

# %%
devices.describe()
# Out:
#        string_field_0 string_field_1
# count           19431          19431
# unique              4          19431
# top           Android      user_6809
# freq             9714              1

# %%
devices.rename(columns={
    "string_field_0": "device_type",
    "string_field_1": "user_id"
},inplace=True)

# %%
devices.head()
# Out:
#   device_type    user_id
# 0       Apple  user_6809
# 1       Apple  user_3636
# 2       Apple   user_510
# 3       Apple  user_3468
# 4       Apple  user_7036

# %%
#Transactions - very big file, will try loading from parquet cache

# %%
csv_path = "/home/neobanking2025/projects/neo_bank/raw_data/transactions.csv"
parquet_path = "/home/neobanking2025/projects/neo_bank/raw_data/transactions.parquet"

if os.path.exists(parquet_path):
    # Load from Parquet cache — fast!
    trans = pd.read_parquet(parquet_path)
else:
    # First time: read CSV (slow)
    trans = pd.read_csv(csv_path)
    # Save cache to Parquet for next time
    trans.to_parquet(parquet_path, index=False)

# %%
trans.head()
# Out:
#         transaction_id transactions_type transactions_currency  amount_usd  \
# 0     transaction_1884            REFUND                   AED        1.76
# 1     transaction_1728            REFUND                   AED      639.31
# 2  transaction_1755782            REFUND                   AED        3.49
# 3     transaction_1973             TOPUP                   AED     6079.39
# 4     transaction_1716             TOPUP                   AED      206.65
#
#   transactions_state ea_cardholderpresence  ea_merchant_mcc ea_merchant_city  \
# 0          COMPLETED                  None              NaN             None
# 1          COMPLETED                  None              NaN             None
# 2          COMPLETED                  None              NaN             None
# 3          COMPLETED                  None              NaN             None
# 4          COMPLETED                  None              NaN             None
#
#   ea_merchant_country direction     user_id                    created_date
# 0                None   INBOUND   user_8098  2018-09-25 16:03:40.978243 UTC
# 1                None   INBOUND    user_182  2018-03-31 13:45:25.262231 UTC
# 2                None   INBOUND  user_14271  2018-11-17 16:47:25.748975 UTC
# 3                None   INBOUND   user_4773  2018-08-13 21:51:28.670363 UTC
# 4                None   INBOUND   user_1363  2018-10-30 14:34:57.479895 UTC

# %%
len(trans)
# Out:
# 2740075

# %%
trans=trans.drop_duplicates()

# %%
len(trans)
# Out:
# 2740075

# %%
trans.describe()
# Out:
#          amount_usd  ea_merchant_mcc
# count  2.740075e+06     1.581417e+06
# mean   1.703225e+05     5.699736e+03
# std    9.634014e+07     9.493660e+02
# min    0.000000e+00     7.420000e+02
# 25%    2.030000e+00     5.411000e+03
# 50%    8.510000e+00     5.812000e+03
# 75%    2.822000e+01     5.921000e+03
# max    8.510645e+10     9.406000e+03

# %%
#users

# %%
users=pd.read_csv("/home/neobanking2025/projects/neo_bank/raw_data/users.csv")
users.head()
# Out:
#       user_id  birth_year country city                    created_date  \
# 0   user_2811        1988      IE    C  2018-03-04 21:46:39.616834 UTC
# 1   user_4750        1987      FR   Ry  2018-04-07 06:49:18.345736 UTC
# 2  user_17686        1984      GB  Ayr  2018-12-04 10:28:02.653147 UTC
# 3  user_18779        1965      GB  Ayr  2018-12-31 07:42:19.353613 UTC
# 4   user_7823        1999      PL  Buk  2018-06-07 03:22:40.590209 UTC
#
#    user_settings_crypto_unlocked      plan  \
# 0                              0  STANDARD
# 1                              0  STANDARD
# 2                              0   PREMIUM
# 3                              0  STANDARD
# 4                              0  STANDARD
#
#    attributes_notifications_marketing_push  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    attributes_notifications_marketing_email  num_contacts  num_referrals  \
# 0                                       NaN             0              0
# 1                                       NaN             0              0
# 2                                       NaN             6              0
# 3                                       NaN             0              0
# 4                                       NaN             0              0
#
#    num_successful_referrals
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0

# %%
len(users)
# Out:
# 19430

# %%
users=users.drop_duplicates()

# %%
len(users)
# Out:
# 19430

# %%
#Notifications

# %%
notifs=pd.read_csv("/home/neobanking2025/projects/neo_bank/raw_data/notifications.csv")
notifs.head()
# Out:
#                reason channel status    user_id  \
# 0  METAL_RESERVE_PLAN     SMS   SENT  user_4703
# 1  METAL_RESERVE_PLAN     SMS   SENT  user_2397
# 2  METAL_RESERVE_PLAN     SMS   SENT  user_2411
# 3  METAL_RESERVE_PLAN     SMS   SENT  user_1119
# 4  METAL_RESERVE_PLAN     SMS   SENT  user_3499
#
#                      created_date
# 0  2018-10-14 01:48:13.319987 UTC
# 1  2018-10-17 08:07:05.709072 UTC
# 2  2018-10-14 03:46:34.244392 UTC
# 3  2018-10-14 14:16:35.801185 UTC
# 4  2018-10-14 18:41:09.268675 UTC

# %%
len(notifs)
# Out:
# 121813

# %%
notifs=notifs.drop_duplicates()

# %%
len(notifs)
# Out:
# 121813

# %% [markdown]
# # Creating Expectations

# %%
context = gx.get_context()

# %% [markdown]
# ## Devices

# %%
devices.head()
# Out:
#   device_type    user_id
# 0       Apple  user_6809
# 1       Apple  user_3636
# 2       Apple   user_510
# 3       Apple  user_3468
# 4       Apple  user_7036

# %%
devices['device_type'].unique()
# Out:
# array(['Apple', 'brand', 'Android', 'Unknown'], dtype=object)

# %%
#since we don't know what "brand" is, let's change it to "unknown" as well

# %%
devices["device_type"] = devices["device_type"].replace("brand", "Unknown")

# %%
devices['device_type'].unique()
# Out:
# array(['Apple', 'Unknown', 'Android'], dtype=object)

# %%
#creates new cleaned parquet file
devices.to_parquet("/home/neobanking2025/projects/neo_bank/cleaned_data/devices.parquet", index=False)

# %%
#checking that all user_ids are a standard length
lengths = devices["user_id"].astype(str).str.len()

min_len = lengths.min()
max_len = lengths.max()

print(f"Min length: {min_len}")
print(f"Max length: {max_len}")
# Out:
# Min length: 6
# Max length: 10

# %%
print("User IDs with the shortest length:")
print(devices[devices["user_id"].astype(str).str.len() == min_len]["user_id"].unique())
# Out:
# User IDs with the shortest length:
# ['user_1' 'user_6' 'user_4' 'user_0' 'user_5' 'user_3' 'user_7' 'user_9'
#  'user_8' 'user_2']

# %%
print("User IDs with the longest length:")
print(devices[devices["user_id"].astype(str).str.len() == max_len]["user_id"].unique())
# Out:
# User IDs with the longest length:
# ['user_11885' 'user_15533' 'user_11964' ... 'user_12296' 'user_19056'
#  'user_12199']

# %%
########

# %%
devices.head()
# Out:
#   device_type    user_id
# 0       Apple  user_6809
# 1       Apple  user_3636
# 2       Apple   user_510
# 3       Apple  user_3468
# 4       Apple  user_7036

# %%
validator = context.sources.pandas_default.read_parquet("/home/neobanking2025/projects/neo_bank/cleaned_data/devices.parquet")

# %%
validator.expect_column_values_to_not_be_null("device_type")
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 19431,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
validator.expect_column_values_to_not_be_null("user_id")
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 19431,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
validator.expect_column_distinct_values_to_be_in_set(
    column="device_type",
    value_set=["Android","Apple","Unknown"]
)
# Out:
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "observed_value": [
#       "Android",
#       "Apple",
#       "Unknown"
#     ],
#     "details": {
#       "value_counts": [
#         {
#           "value": "Android",
#           "count": 9714
#         },
#         {
#           "value": "Apple",
#           "count": 9673
#         },
#         {
#           "value": "Unknown",
#           "count": 44
#         }
#       ]
#     }
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
validator.expect_column_values_to_match_regex(
    column="user_id",
    regex=r"^user_"
)
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 19431,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
validator.expect_column_value_lengths_to_be_between(
    column="user_id",
    min_value=6,
    max_value=10
)
# Out:
# Calculating Metrics:   0%|          | 0/9 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 19431,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ## Transactions

# %%
trans.head()
# Out:
#         transaction_id transactions_type transactions_currency  amount_usd  \
# 0     transaction_1884            REFUND                   AED        1.76
# 1     transaction_1728            REFUND                   AED      639.31
# 2  transaction_1755782            REFUND                   AED        3.49
# 3     transaction_1973             TOPUP                   AED     6079.39
# 4     transaction_1716             TOPUP                   AED      206.65
#
#   transactions_state ea_cardholderpresence  ea_merchant_mcc ea_merchant_city  \
# 0          COMPLETED                  None              NaN             None
# 1          COMPLETED                  None              NaN             None
# 2          COMPLETED                  None              NaN             None
# 3          COMPLETED                  None              NaN             None
# 4          COMPLETED                  None              NaN             None
#
#   ea_merchant_country direction     user_id                    created_date
# 0                None   INBOUND   user_8098  2018-09-25 16:03:40.978243 UTC
# 1                None   INBOUND    user_182  2018-03-31 13:45:25.262231 UTC
# 2                None   INBOUND  user_14271  2018-11-17 16:47:25.748975 UTC
# 3                None   INBOUND   user_4773  2018-08-13 21:51:28.670363 UTC
# 4                None   INBOUND   user_1363  2018-10-30 14:34:57.479895 UTC

# %%
trans['transactions_type'].unique()
# Out:
# array(['REFUND', 'TOPUP', 'EXCHANGE', 'TRANSFER', 'CARD_PAYMENT',
#        'CARD_REFUND', 'ATM', 'FEE', 'CASHBACK', 'TAX'], dtype=object)

# %%
trans['transactions_currency'].unique()
# Out:
# array(['AED', 'AUD', 'BCH', 'BGN', 'BTC', 'CAD', 'CHF', 'CZK', 'DKK',
#        'ETH', 'EUR', 'GBP', 'HKD', 'HRK', 'HUF', 'ILS', 'INR', 'JPY',
#        'LTC', 'MAD', 'MXN', 'NOK', 'NZD', 'PLN', 'QAR', 'RON', 'RUB',
#        'SAR', 'SEK', 'SGD', 'THB', 'TRY', 'USD', 'XRP', 'ZAR'],
#       dtype=object)

# %%
trans['amount_usd'].max()
# Out:
# 85106453190.03

# %%
trans['amount_usd'].min()
# Out:
# 0.0

# %%
trans.dtypes
# Out:
# transaction_id            object
# transactions_type         object
# transactions_currency     object
# amount_usd               float64
# transactions_state        object
# ea_cardholderpresence     object
# ea_merchant_mcc          float64
# ea_merchant_city          object
# ea_merchant_country       object
# direction                 object
# user_id                   object
# created_date              object
# dtype: object

# %%
trans['created_date'] = pd.to_datetime(trans['created_date'],errors='coerce').dt.tz_localize(None)

# %%
trans = trans.dropna(subset=['created_date'])

# %%
trans.head()
# Out:
#         transaction_id transactions_type transactions_currency  amount_usd  \
# 0     transaction_1884            REFUND                   AED        1.76
# 1     transaction_1728            REFUND                   AED      639.31
# 2  transaction_1755782            REFUND                   AED        3.49
# 3     transaction_1973             TOPUP                   AED     6079.39
# 4     transaction_1716             TOPUP                   AED      206.65
#
#   transactions_state ea_cardholderpresence  ea_merchant_mcc ea_merchant_city  \
# 0          COMPLETED                  None              NaN             None
# 1          COMPLETED                  None              NaN             None
# 2          COMPLETED                  None              NaN             None
# 3          COMPLETED                  None              NaN             None
# 4          COMPLETED                  None              NaN             None
#
#   ea_merchant_country direction     user_id               created_date
# 0                None   INBOUND   user_8098 2018-09-25 16:03:40.978243
# 1                None   INBOUND    user_182 2018-03-31 13:45:25.262231
# 2                None   INBOUND  user_14271 2018-11-17 16:47:25.748975
# 3                None   INBOUND   user_4773 2018-08-13 21:51:28.670363
# 4                None   INBOUND   user_1363 2018-10-30 14:34:57.479895

# %%
trans.dtypes
# Out:
# transaction_id                   object
# transactions_type                object
# transactions_currency            object
# amount_usd                      float64
# transactions_state               object
# ea_cardholderpresence            object
# ea_merchant_mcc                 float64
# ea_merchant_city                 object
# ea_merchant_country              object
# direction                        object
# user_id                          object
# created_date             datetime64[ns]
# dtype: object

# %%
trans['transactions_state'].unique()
# Out:
# array(['COMPLETED', 'CANCELLED', 'DECLINED', 'PENDING', 'REVERTED',
#        'FAILED'], dtype=object)

# %%
trans['ea_cardholderpresence'].unique()
##fix
# Out:
# array([None, 'FALSE', 'TRUE', 'UNKNOWN'], dtype=object)

# %%
trans['ea_cardholderpresence'] = trans['ea_cardholderpresence'].fillna("UNKNOWN")

# %%
trans['ea_cardholderpresence'].unique()
# Out:
# array(['UNKNOWN', 'FALSE', 'TRUE'], dtype=object)

# %%
trans['ea_cardholderpresence'].isnull().sum()
# Out:
# 0

# %%
trans['ea_merchant_mcc'].unique()
#drop
# Out:
# array([  nan, 9222., 4111., 4112., 5651., 5912., 4121., 5661., 5921.,
#        5411., 5941., 7221., 5942., 5943., 7991., 3612., 5944., 5945.,
#        7994., 5691., 5947., 5948., 7996., 7997., 7230., 7999., 5441.,
#        3750., 5964., 5712., 5968., 5969., 5971., 8021., 7512., 5977.,
#        3503., 3504., 7011., 7523., 5734., 4457., 3509., 5994., 7278.,
#        5999., 3512., 3640., 6513., 3641., 4722., 4215., 5499., 6011.,
#        8062., 3520., 7299., 5511., 7832., 4511., 8099., 5541., 5542.,
#        3543., 5039., 5811., 5812., 5813., 5814., 5047., 5309., 5311.,
#        7372., 4814., 5331., 7392., 4582., 7399., 5611., 7922., 5621.,
#        7929., 7933., 3583., 5631., 8299., 9399., 7941., 5641., 3079.,
#        8220., 5399., 5655., 4131., 4899., 7211., 5932., 5422., 5172.,
#        5940., 4411., 7995., 3615., 7998., 5699., 5192., 5451., 8011.,
#        5199., 5200., 5714., 5970., 5462., 5719., 5722., 9402., 7519.,
#        5732., 5733., 5735., 8398., 5993., 5995., 7538., 8050., 3642.,
#        7542., 7033., 7296., 7298., 5251., 3395., 3012., 7311., 5521.,
#        5013., 6300., 5533., 6051., 7333., 4789., 5816., 5817., 3551.,
#        5310., 1520., 5571., 4812., 4816., 4818., 7394., 7395., 5099.,
#        5111., 7932., 8249., 8911., 8999., 8641., 8699., 7993., 4784.,
#        5967., 2741., 5045., 5815., 3717., 5131., 7210., 5931., 3357.,
#        3366., 5965., 3246., 3502., 5992., 8041., 8043., 4468., 3005.,
#        3390., 4225., 3009., 5261., 7829., 3405., 7338., 5300., 5046.,
#        3552., 3047., 5072.,  763., 3180., 5094., 8675., 3077., 3720.,
#        5139., 3211., 8244.,  742., 7216., 3355., 5946., 3102., 5949.,
#        5950., 5697., 6211., 5193., 5962., 4011., 3245., 3501., 5983.,
#        3381., 3510., 5997., 7277., 7534., 3001., 3771., 7032., 3389.,
#        6010., 3518., 6012., 3007., 3008., 3136., 3010., 3011., 6540.,
#        3015., 3655., 3016., 7321., 3533., 3025., 7349., 5561., 5818.,
#        3039., 7361., 3043., 3811., 3301., 2791., 7379., 3182., 4829.,
#        5085., 3058., 3064., 3579., 9405., 3072., 5122., 7699., 4119.,
#        3084., 4900., 3351., 5169., 5681., 7992., 3236., 5198., 5713.,
#        5211., 7273., 5996., 4214., 7297., 8071., 3029., 5551., 8111.,
#        5044., 7375., 9311., 8351., 1731., 1799., 5963., 1750., 5998.,
#        5065., 1473., 3075., 3715., 1346., 1474., 1411., 3590., 3591.,
#        3719., 8734., 1348., 1476., 3592., 5137., 3721., 1413., 1477.,
#        3722., 5911., 3596., 5913., 1415., 1480., 3088., 2961., 1353.,
#        3602., 4133., 3219., 1354., 1418., 3220., 3604., 1355., 1483.,
#        5933., 5935., 1420., 1740., 5937., 7217., 7987., 2842., 3099.,
#        7990., 3100., 3741., 1423., 7231., 1424., 1488., 5952., 5698.,
#        5956., 5957., 3619., 5959., 1490., 2340., 5960., 3745., 3513.,
#        3831., 3710., 3747., 3649., 7342., 3034., 7841., 5972., 3256.,
#        3690., 5966., 5976., 5231., 3643., 5271., 3022., 3538., 3028.,
#        7339., 3030., 2523., 3294., 3183., 7911., 3078., 3637., 3260.,
#        5051., 7622., 7393., 3196., 3581., 3217., 3076., 3716., 7692.,
#        1350., 1351., 3730., 1419., 3608., 7988., 3614., 3742., 3103.,
#        1360., 7232., 1425., 1362., 3751., 3240., 3368., 3625., 7251.,
#        1493., 5973., 5975., 2348., 4012., 7513., 5978., 1431., 3247.,
#         780., 3506., 3634., 7012., 7013., 1370., 1434., 3636., 8042.,
#        7531., 7276., 1372., 1436., 3000., 8049., 3769., 7539., 2490.,
#        3387., 2014., 3516., 3773., 3774., 3519., 2369., 3393., 3778.,
#        6533., 3779., 3652., 3780., 6537., 3013., 6538., 2376., 3144.,
#        1381., 1445., 3530., 3659., 2380., 3661., 5531., 5532., 5021.,
#        3535., 3663., 3665., 3793., 1449., 3026., 3667., 5543., 1771.,
#        3031., 2520., 3672., 3545., 1453., 3035., 1390., 2524., 3548.,
#        3676., 3804., 3549., 3677., 1711., 5313., 3297., 3553., 1521.,
#        3042., 1522., 3812., 3813., 4813., 7629., 3687., 7631., 1396.,
#        3048., 5074., 1397., 3562., 4821., 5333., 3051., 5335., 1462.,
#        3052., 3692., 5592., 7641., 2541., 3181., 5338., 5598., 5599.,
#        3056., 3441., 1401., 1465., 3698., 3826., 5350., 1338., 1402.,
#        3700., 1339., 1403., 1531., 2422., 3830., 3703., 1340., 3577.,
#        1405., 1469., 1406., 1470., 3068., 2941., 3709., 1407., 8211.,
#        8411., 8931., 8651., 8661., 9211., 3623., 5718., 1366., 1430.,
#        8031., 3248., 3511., 7535., 1373., 3515., 3132., 3261., 7549.,
#        1504., 3650., 3524., 3653., 3014., 3526., 3654., 3018., 3020.,
#        3021., 3662., 3791., 2131., 2133., 3542., 1452., 3032., 1454.,
#        2525., 3037., 1391., 3808., 2401., 3174., 3050., 3824., 1466.,
#        3829., 3575., 3066., 1471., 8241., 2013., 3190., 3589., 3082.,
#        1481., 1486., 1487., 5955., 3586., 3740., 3621., 3508., 3767.,
#        1761., 6536., 2501., 3017., 3657., 3790., 3668., 3040., 1395.,
#        3828., 3098., 3299., 3628., 9406., 3638., 3784., 3295., 3770.,
#        3613., 3765., 3777., 3782., 3816., 3695., 3825., 1495., 7261.,
#        7014., 1498., 8412., 3517., 2111., 1382., 2528., 3681., 3555.,
#        3175., 3049., 1398., 1342., 4124., 3609., 1376., 3788., 3223.,
#        3266., 3617., 3127., 3644., 3057., 3206., 3607., 5939., 3635.,
#        3267., 3523., 3024., 3832., 3161., 3598., 3731., 3660.])

# %%
uv = trans['ea_merchant_city'].unique()
print(list(uv))
#drop
# Out:
# [None, 'Dubai', 'tfl.gov.uk/cp', 'Stockholm', 'M?nchen-flugh', 'Abu Dhabi', 'Paris', 'Abudhabi', 'Tallinn', 'Hamburg', '800-592-8996', 'Vorden', 'help.uber.com', 'Ras Alkhaimah', 'Dxb', 'Ras Al Khaima', 'Sharjah', 'Reykjanesbaer', 'Amsterdam', 'Swindon', 'Madrid', 'London', 'G.co Helppay#', 'www.amazon.co', 'Muenchen', 'Rak', 'Fujairah', 'Koebenhavn V', 'Paris 5', '415-800-5959', 'St. Albans', 'groupon.ae', '35314369001', 'Auh', 'Poznan', 'Abu Dhabi Ua', '123', 'Dubai       H', 'Abu Dhabi Uae', 'Arjah      A', 'Nakheel', 'Dubai Uae', 'Dubai Mins R', 'Fuj', 'Bai        A', 'Kielce', '8004049723', 'Koebenhavn K', 'Bucuresti', 'Stockholmarla', 'Ajman', '97165554545', 'Reykjavik', 'M?nchen', 'Dublin', 'Horley 012937', 'Fiumicino', 'Stockholm-arl', '03456 049 049', 'Siauliai', 'Elk Grove Vil', 'g.co/helppay#', 'Foster City', 'Newmarket', 'Sydney', 'Castle Hill', 'Melbourne', 'Australia', 'University Of', 'Hong Kong', 'Brisbane', 'Burnley', 'Chippendale', 'Subiaco', 'Mosman Park', 'South Brisban', 'Fremantle', 'Haymarket', 'Cottesloe', 'Manly', 'East Perth', 'Southport', 'Fortitude Val', 'Surfers Parad', 'Pyrmont', 'Perth', 'Helensvale', 'Maddington', '61390275076', 'Oakleigh East', 'Mandurah', 'Brighton', 'Balaclava', 'Murdoch', 'Perth Airport', 'Noosa Heads', 'Broadbeach', 'Bondi Junctio', 'Airlie Beach', 'Santa Gertrud', 'Sydney South', 'Lidcombe', 'Kennett River', 'Byron Bay', 'Marrickville', 'Morayfield', 'Milton', 'Bondi Beach', 'Scarborough', 'Mulgrave', 'Dunwich', 'San Marcos', 'Joondalup', 'Windsor', 'Burpengary', 'Leura', 'West End', 'Woollahra', 'Huskisson', 'Colebee', 'Paddington', 'Rainbow Beach', 'Rutherford', 'Hobart', 'Oaklands Park', 'Drummoyne', 'Port Douglas', 'Mascot', 'Enmore', '4029357733', 'Bundaberg', 'Gymea', 'Redcliffe', 'Kellyville', 'Wollongong', 'Cannonvale', 'Surry Hills', 'Mount Sherida', 'Singapore', '14518236738', 'Eveleigh Nsw', 'Portsmith', 'Alexandria', 'West Melbourn', 'Help.u', 'Victoria Park', '800592', 'Help.uber.c', 'Cairns', 'Rouse Hill', 'Healesville', 'St Marys', 'Sunshine Beac', 'Fairfield', 'Fitzroy', 'Nelly Bay', 'Yeronga', 'Mt Pleasant', 'Sunrise Beach', 'Henley Brook', 'Lawson', 'Carlton North', 'Caulfield Sou', 'North Lakes', 'St Kilda', 'Woolgoolga', 'Cootamundra', 'Gatton', 'Rushcutters B', 'Southbank', 'Iluka', 'Herne Hill', 'Redfern', 'Pokolbin', 'Chirn Park', 'Colac', 'South Melbour', 'Randwick', 'Ballina', 'Rockhampton D', 'Coldstream', 'Potts Point', 'Maroubra', 'Banora Point', 'Moorooka', 'Zetland', 'Mooloolaba', 'Noarlunga Cen', 'Newtown', 'Yering', 'Darlinghurst', 'Prahran', 'Clovelly', 'Lakes Entranc', 'Springwood', 'Elizabeth Bay', 'West Perth', 'Pemberton', 'Rose Bay', 'Agnes Water', 'Childers', 'Hazelbrook', 'South Grafton', 'Swansea', 'Melbourne Air', 'Eagle Farm', 'Stansted', 'Queenstown', 'Airport West', 'Vincentia', 'Chermside', 'Canberra', 'Bondi Jct', 'Sunshine Nort', 'Falcon', 'Rosebery', 'Fitzroy North', 'East Gresford', 'Kununurra', 'Newcastle', 'Broadway', 'Edgecliff', 'Chelsea', 'Salaman Bay', 'Carlton', 'Mackay', 'East Sydney', 'Erskine', 'Caloundra', 'Townsville', 'North Mackay', 'Seven Hills', 'Yulara', 'Sth Fremantle', 'Grafton', 'Warrnambool', 'Belconnen', 'Nimbin', 'Hervey Bay', 'Richmond', 'Rye', 'Darwin', 'Coogee', 'Kardinya', 'Bucasia', 'Eastlakes', 'Tannum Sands', 'Bellingen', 'Caulfield', 'Wolli Creek', 'Oakleigh', 'Braidwood', 'Prt Macquarie', 'Salamander Ba', 'South Yarra', 'Elanora', 'Chadstone', 'Stafford', 'Yandina', 'Halls Head', 'Blacktown', 'Moonee Beach', 'San Remo', 'New Farm', 'Docklands', 'Mentone', 'Waterloo', 'Katoomba', 'Cannington', 'Bunbury', 'Alexandra', 'Emu Plains', 'Safety Bay', 'Palm Beach', 'Redlynch', 'Coffs Harbour', 'Kingscliff', 'Winmalee', 'Apollo Bay', 'Dapto', 'Paterson', 'Alice Springs', 'Deer Park', 'Warwick', 'Collingwood', 'Lorne', 'Kings Cross', 'Annerley', 'Toowoomba', 'Hornsby', 'Burleigh Head', 'North Lake', 'Werribee', 'Surfers Pdise', 'Asquith', 'Kallangur', 'Inglewood', 'Neutral Bay', 'Sth Hurstvill', 'Bondi ...

# %%
trans['ea_merchant_country'].unique()
# Out:
# array([None, 'ARE', 'GBR', 'SWE', 'DEU', 'FRA', 'EST', 'NLD', 'POL',
#        'ISL', 'ESP', 'USA', 'LUX', 'DNK', 'IRL', 'JOR', 'ROM', 'ITA',
#        'LTU', 'AUS', 'HKG', 'SGP', 'NZL', 'FJI', 'IDN', 'CHE', 'MYS',
#        'CHN', 'VNM', 'BGR', 'MNE', 'NOR', 'ISR', 'BEL', 'CYP', 'CZE',
#        'ROU', 'GIB', 'EGY', 'PRT', 'CAN', 'ZAF', 'MEX', 'COL', 'PER',
#        'ARG', 'HUN', 'LKA', 'BOL', 'BRA', 'LVA', 'THA', 'RUS', 'FIN',
#        'AUT', 'HRV', 'GRC', 'JPN', 'REU', 'SRB', 'BIH', 'CHL', 'TTO',
#        'LBN', 'IND', 'KAZ', 'CRI', 'TWN', 'TUR', 'URY', 'AND', 'QAT',
#        'LIE', 'BHS', 'MAR', 'MUS', 'OMN', 'MLT', 'BMU', 'UGA', 'ARM',
#        'SYC', 'PHL', 'KEN', 'MCO', 'MDV', 'UZB', 'GEO', 'ETH', 'MOZ',
#        'TCA', 'NPL', 'JAM', 'CUB', 'LAO', 'UKR', 'KHM', 'SVN', 'VCT',
#        'SVK', 'BLR', 'PAN', 'MMR', 'DOM', 'TZA', 'ECU', 'MKD', 'VAT',
#        'HND', 'GTM', 'PYF', 'KOR', 'SXM', 'MTQ', 'PRI', 'GLP', 'MNG',
#        'TUN', 'NGA', 'AGO', 'VEN', 'SAU', 'NER', 'ATG', 'MDA', 'MYT',
#        'PRY', 'SEN', 'NCL', 'CIV', 'KGZ', 'ZWE', 'BLZ', 'BWA', 'COK',
#        'NAM', 'BHR', 'AZE', 'FRO', 'GIN', 'BRB', 'KWT', 'ALB', 'PSE',
#        'SMR', 'MDG', 'CUW', 'CYM', 'LCA', 'BFA', 'QZZ', 'ZMB', 'NIC',
#        'SLV', 'GUF', 'VIR', 'MAC', 'BEN', 'ZAR', 'CPV', 'GHA', 'SUR',
#        'CMR', 'GNQ', 'COD', 'GAB', 'DZA', 'ANT', 'GMB', 'PCN', 'PAK',
#        'TCD', 'APT', 'GGY', 'RWA', 'DMA', 'TGO', 'HMD', 'GUY', 'AGB',
#        'MAF', 'BRN', 'IMN', 'ABW', 'TKM', 'BGD', 'JEY', 'MWI', 'GRD',
#        'KNA', 'VUT', 'PGB', 'VGB', 'SWZ', 'LSO', 'AIA', 'TON', 'SGB',
#        'SCH'], dtype=object)

# %%
trans['ea_merchant_country'] = trans['ea_merchant_country'].fillna("UNKNOWN")

# %%
trans['direction'].unique()
# Out:
# array(['INBOUND', 'OUTBOUND'], dtype=object)

# %%
#drop some columns we don't need
trans = trans.drop(["ea_merchant_city", "ea_merchant_mcc"], axis=1)

# %%
#creates new clean file
trans.to_parquet("/home/neobanking2025/projects/neo_bank/cleaned_data/transactions.parquet", index=False)

# %%
#######

# %%
validator = context.sources.pandas_default.read_parquet("/home/neobanking2025/projects/neo_bank/cleaned_data/transactions.parquet")

# %%
trans.head(2)
# Out:
#      transaction_id transactions_type transactions_currency  amount_usd  \
# 0  transaction_1884            REFUND                   AED        1.76
# 1  transaction_1728            REFUND                   AED      639.31
#
#   transactions_state ea_cardholderpresence ea_merchant_country direction  \
# 0          COMPLETED               UNKNOWN             UNKNOWN   INBOUND
# 1          COMPLETED               UNKNOWN             UNKNOWN   INBOUND
#
#      user_id               created_date
# 0  user_8098 2018-09-25 16:03:40.978243
# 1   user_182 2018-03-31 13:45:25.262231

# %%
for col in ["created_date", "user_id", "transaction_id","transactions_type","transactions_currency","amount_usd","transactions_state","ea_cardholderpresence","ea_merchant_country"]:
    result = validator.expect_column_values_to_not_be_null(col)
    print(f"Expectation for '{col}':", result)
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'created_date': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "created_date",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 2740071,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'user_id': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "user_id",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 2740071,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'transaction_id': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "transaction_id",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 2740071,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'transactions_type': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "transactions_type",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 2740071,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'transactions_currency': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "transactions_currency",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 2740071,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'amount_usd': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "amount_usd",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 2740071,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'transactions_state': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "transactions_state",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 2740071,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'ea_cardholderpresence': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "ea_cardholderpresence",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 2740071,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'ea_merchant_country': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "ea_merchant_country",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 2740071,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
trans['created_date'].min()
# Out:
# Timestamp('2018-01-01 08:51:10.248709')

# %%
trans['created_date'].max()
# Out:
# Timestamp('2019-05-16 18:22:16.959896')

# %%
trans['created_date'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Users

# %%
users.head()
# Out:
#       user_id  birth_year country city                    created_date  \
# 0   user_2811        1988      IE    C  2018-03-04 21:46:39.616834 UTC
# 1   user_4750        1987      FR   Ry  2018-04-07 06:49:18.345736 UTC
# 2  user_17686        1984      GB  Ayr  2018-12-04 10:28:02.653147 UTC
# 3  user_18779        1965      GB  Ayr  2018-12-31 07:42:19.353613 UTC
# 4   user_7823        1999      PL  Buk  2018-06-07 03:22:40.590209 UTC
#
#    user_settings_crypto_unlocked      plan  \
# 0                              0  STANDARD
# 1                              0  STANDARD
# 2                              0   PREMIUM
# 3                              0  STANDARD
# 4                              0  STANDARD
#
#    attributes_notifications_marketing_push  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    attributes_notifications_marketing_email  num_contacts  num_referrals  \
# 0                                       NaN             0              0
# 1                                       NaN             0              0
# 2                                       NaN             6              0
# 3                                       NaN             0              0
# 4                                       NaN             0              0
#
#    num_successful_referrals
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0

# %%
users['birth_year'].min()
# Out:
# 1929

# %%
users['birth_year'].max()
# Out:
# 2001

# %%
users.drop(columns={'city'},inplace=True)

# %%
users['plan'].unique()
# Out:
# array(['STANDARD', 'PREMIUM', 'METAL', 'METAL_FREE', 'PREMIUM_OFFER',
#        'PREMIUM_FREE'], dtype=object)

# %%
users['user_settings_crypto_unlocked'].unique()
# Out:
# array([0, 1])

# %%
users['attributes_notifications_marketing_push'].unique()
# Out:
# array([nan,  1.,  0.])

# %%
users['attributes_notifications_marketing_push'].value_counts()
# Out:
# attributes_notifications_marketing_push
# 1.0    12148
# 0.0      672
# Name: count, dtype: int64

# %%
users['attributes_notifications_marketing_push'].isnull().sum()
# Out:
# 6610

# %%
users['attributes_notifications_marketing_push'] = users['attributes_notifications_marketing_push'].round().astype('Int64')

# %%
users['attributes_notifications_marketing_email'].unique()
# Out:
# array([nan,  0.,  1.])

# %%
users['attributes_notifications_marketing_email'].value_counts()
# Out:
# attributes_notifications_marketing_email
# 1.0    11486
# 0.0     1334
# Name: count, dtype: int64

# %%
users['attributes_notifications_marketing_email'].isnull().sum()
# Out:
# 6610

# %%
users['attributes_notifications_marketing_email'] = users['attributes_notifications_marketing_email'].round().astype('Int64')

# %%
users['num_contacts'].min()
# Out:
# 0

# %%
users['num_contacts'].max()
# Out:
# 2918

# %%
users['num_referrals'].unique()
# Out:
# array([0])

# %%
users['num_referrals'].min()
# Out:
# 0

# %%
users['num_referrals'].max()
# Out:
# 0

# %%
users.drop(columns={'num_referrals'},inplace=True)

# %%
users['num_successful_referrals'].min()
# Out:
# 0

# %%
users['num_successful_referrals'].max()
# Out:
# 0

# %%
users.drop(columns={'num_successful_referrals'},inplace=True)

# %%
users['country'].unique()
# Out:
# array(['IE', 'FR', 'GB', 'PL', 'ES', 'NO', 'BE', 'SI', 'IT', 'RO', 'CH',
#        'DE', 'CZ', 'HU', 'GR', 'NL', 'MT', 'SE', 'PT', 'LT', 'FI', 'LV',
#        'EE', 'AT', 'CY', 'HR', 'LU', 'BG', 'DK', 'GG', 'GP', 'JE', 'AU',
#        'SK', 'LI', 'IM', 'IS', 'GI', 'MQ', 'GF', 'RE'], dtype=object)

# %%
users['created_date'] = pd.to_datetime(users['created_date'],errors='coerce').dt.tz_localize(None)

# %%
users['created_date'].min()
# Out:
# Timestamp('2018-01-01 08:42:24.799709')

# %%
users['created_date'].max()
# Out:
# Timestamp('2019-01-03 07:34:36.638892')

# %%
#creates new clean file
users.to_parquet("/home/neobanking2025/projects/neo_bank/cleaned_data/users.parquet", index=False)

# %%
#####

# %%
users.columns
# Out:
# Index(['user_id', 'birth_year', 'country', 'created_date',
#        'user_settings_crypto_unlocked', 'plan',
#        'attributes_notifications_marketing_push',
#        'attributes_notifications_marketing_email', 'num_contacts'],
#       dtype='object')

# %%
validator = context.sources.pandas_default.read_parquet("/home/neobanking2025/projects/neo_bank/cleaned_data/users.parquet")

# %%
for col in ["user_id", "birth_year","country","created_date","user_settings_crypto_unlocked","plan","num_contacts"]:
    result = validator.expect_column_values_to_not_be_null(col)
    print(f"Expectation for '{col}':", result)
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'user_id': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "user_id",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 19430,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'birth_year': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "birth_year",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 19430,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'country': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "country",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 19430,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'created_date': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "created_date",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 19430,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'user_settings_crypto_unlocked': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "user_settings_crypto_unlocked",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 19430,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'plan': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "plan",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 19430,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Expectation for 'num_contacts': {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "num_contacts",
#       "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 19430,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
validator.expect_column_values_to_be_unique(column='user_id')
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 19430,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# # Sending Cleaned Data to GCP Cloud Storage Bucket

# %%
# from google.cloud import storage

# %%
def upload_to_gcs(bucket_name, source_file_path, destination_blob_name):
    """Uploads a file to the GCS bucket."""
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)

    blob.upload_from_filename(source_file_path)
    print(f"Uploaded {source_file_path} to gs://{bucket_name}/{destination_blob_name}")

# %%
# upload_to_gcs(
#     bucket_name="neobank_data_bucket",
#     source_file_path="/home/neobanking2025/projects/neo_bank/cleaned_data/transactions.parquet",
#     destination_blob_name="staging_data/"
# )
# Out:
# ---------------------------------------------------------------------------
# InvalidResponse                           Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/cloud/storage/blob.py:2700, in Blob._prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2699 try:
# -> 2700     created_json = self._do_upload(
#    2701         client,
#    2702         file_obj,
#    2703         content_type,
#    2704         size,
#    2705         num_retries,
#    2706         predefined_acl,
#    2707         if_generation_match,
#    2708         if_generation_not_match,
#    2709         if_metageneration_match,
#    2710         if_metageneration_not_match,
#    2711         timeout=timeout,
#    2712         checksum=checksum,
#    2713         retry=retry,
#    2714         command=command,
#    2715     )
#    2716     self._set_properties(created_json)
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/cloud/storage/blob.py:2523, in Blob._do_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2522 else:
# -> 2523     response = self._do_resumable_upload(
#    2524         client,
#    2525         stream,
#    2526         content_type,
#    2527         size,
#    2528         num_retries,
#    2529         predefined_acl,
#    2530         if_generation_match,
#    2531         if_generation_not_match,
#    2532         if_metageneration_match,
#    2533         if_metageneration_not_match,
#    2534         timeout=timeout,
#    2535         checksum=checksum,
#    2536         retry=retry,
#    2537         command=command,
#    2538     )
#    2540 return response.json()
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/cloud/storage/blob.py:2329, in Blob._do_resumable_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2232 """Perform a resumable upload.
#    2233
#    2234 Assumes ``chunk_size`` is not :data:`None` on the current blob.
#    (...)
#    2327           is uploaded.
#    2328 """
# -> 2329 upload, transport = self._initiate_resumable_upload(
#    2330     client,
#    2331     stream,
#    2332     content_type,
#    2333     size,
#    2334     num_retries,
#    2335     predefined_acl=predefined_acl,
#    2336     if_generation_match=if_generation_match,
#    2337     if_generation_not_match=if_generation_not_match,
#    2338     if_metageneration_match=if_metageneration_match,
#    2339     if_metageneration_not_match=if_metageneration_not_match,
#    2340     timeout=timeout,
#    2341     checksum=checksum,
#    2342     retry=retry,
#    2343     command=command,
#    2344 )
#    2345 extra_attributes = {
#    2346     "url.full": upload.resumable_url,
#    2347     "upload.chunk_size": upload.chunk_size,
#    2348     "upload.checksum": f"{checksum}",
#    2349 }
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/cloud/storage/blob.py:2203, in Blob._initiate_resumable_upload(self, client, stream, content_type, size, num_retries, predefined_acl, extra_headers, chunk_size, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2199 upload._retry_strategy = _api_core_retry_to_resumable_media_retry(
#    2200     retry, num_retries
#    2201 )
# -> 2203 upload.initiate(
#    2204     transport,
#    2205     stream,
#    2206     object_metadata,
#    2207     content_type,
#    2208     total_bytes=size,
#    2209     stream_final=False,
#    2210     timeout=timeout,
#    2211 )
#    2213 return upload, transport
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/resumable_media/requests/upload.py:420, in ResumableUpload.initiate(self, transport, stream, metadata, content_type, total_bytes, stream_final, timeout)
#     418     return result
# --> 420 return _request_helpers.wait_and_retry(
#     421     retriable_request, self._get_status_code, self._retry_strategy
#     422 )
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/resumable_media/requests/_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/resumable_media/requests/upload.py:416, in ResumableUpload.initiate.<locals>.retriable_request()
#     412 result = transport.request(
#     413     method, url, data=payload, headers=headers, timeout=timeout
#     414 )
# --> 416 self._process_initiate_response(result)
#     418 return result
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/resumable_media/_upload.py:518, in ResumableUpload._process_initiate_response(self, response)
#     503 """Process the response from an HTTP request that initiated upload.
#     504
#     505 This is everything that must be done after a request that doesn't
#    (...)
#     516 .. _sans-I/O: https://sans-io.readthedocs.io/
#     517 """
# --> 518 _helpers.require_status_code(
#     519     response,
#     520     (http.client.OK, http.client.CREATED),
#     521     self._get_status_code,
#     522     callback=self._make_invalid,
#     523 )
#     524 self._resumable_url = _helpers.header_required(
#     525     response, "location", self._get_headers
#     526 )
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/resumable_media/_helpers.py:108, in require_status_code(response, status_codes, get_status_code, callback)
#     107         callback()
# --> 108     raise common.InvalidResponse(
#     109         response,
#     110         "Request failed with status code",
#     111         status_code,
#     112         "Expected one of",
#     113         *status_codes
#     114     )
#     115 return status_code
#
# InvalidResponse: ('Request failed with status code', 403, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.CREATED: 201>)
#
# During handling of the above exception, another exception occurred:
#
# Forbidden                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 upload_to_gcs(
#       2     bucket_name="neobank_data_bucket",
#       3     source_file_path="/home/neobanking2025/projects/neo_bank/cleaned_data/transactions.parquet",
#       4     destination_blob_name="staging_data/"
#       5 )
#
# Cell In[108], line 7, in upload_to_gcs(bucket_name, source_file_path, destination_blob_name)
#       4 bucket = client.bucket(bucket_name)
#       5 blob = bucket.blob(destination_blob_name)
# ----> 7 blob.upload_from_filename(source_file_path)
#       8 print(f"Uploaded {source_file_path} to gs://{bucket_name}/{destination_blob_name}")
#
# File /usr/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/cloud/storage/blob.py:3006, in Blob.upload_from_filename(self, filename, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    2892 @create_trace_span(name="Storage.Blob.uploadFromFilename")
#    2893 def upload_from_filename(
#    2894     self,
#    (...)
#    2906     retry=DEFAULT_RETRY_IF_GENERATION_SPECIFIED,
#    2907 ):
#    2908     """Upload this blob's contents from the content of a named file.
#    2909
#    2910     The content type of the upload will be determined in order
#    (...)
#    3003         such as delays and deadlines are respected.
#    3004     """
# -> 3006     self._handle_filename_and_upload(
#    3007         filename,
#    3008         content_type=content_type,
#    3009         num_retries=num_retries,
#    3010         client=client,
#    3011         predefined_acl=predefined_acl,
#    3012         if_generation_match=if_generation_match,
#    3013         if_generation_not_match=if_generation_not_match,
#    3014         if_metageneration_match=if_metageneration_match,
#    3015         if_metageneration_not_match=if_metageneration_not_match,
#    3016         timeout=timeout,
#    3017         checksum=checksum,
#    3018         retry=retry,
#    3019     )
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/cloud/storage/blob.py:2884, in Blob._handle_filename_and_upload(self, filename, content_type, *args, **kwargs)
#    2882 with open(filename, "rb") as file_obj:
#    2883     total_bytes = os.fstat(file_obj.fileno()).st_size
# -> 2884     self._prep_and_do_upload(
#    2885         file_obj,
#    2886         content_type=content_type,
#    2887         size=total_bytes,
#    2888         *args,
#    2889         **kwargs,
#    2890     )
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/cloud/storage/blob.py:2718, in Blob._prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2716     self._set_properties(created_json)
#    2717 except resumable_media.InvalidResponse as exc:
# -> 2718     _raise_from_invalid_response(exc)
#
# File ~/.cache/pypoetry/virtualenvs/02-upload-H49HWJRV-py3.10/lib/python3.10/site-packages/google/cloud/storage/blob.py:4908, in _raise_from_invalid_response(error)
#    4904     error_message = str(error)
#    4906 message = f"{response.request.method} {response.request.url}: {error_message}"
# -> 4908 raise exceptions.from_http_status(response.status_code, message, response=response)
#
# Forbidden: 403 POST https://storage.googleapis.com/upload/storage/v1/b/neobank_data_bucket/o?uploadType=resumable: {
#   "error": {
#     "code": 403,
#     "message": "Provided scope(s) are not authorized",
#     "errors": [
#       {
#         "message": "Provided scope(s) are not authorized",
#         "domain": "global",
#         "reason": "forbidden"
#       }
#     ]
#   }
# }
# : ('Request failed with status code', 403, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.CREATED: 201>)
